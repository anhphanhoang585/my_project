# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
music_data = pd.read_csv("C:/Users/ADMIN/Documents/music.csv")
X = music_data.drop(columns=['genre'])
Y = music_data['genre']
model = DecisionTreeClassifier()
model.fit(X, Y)
pre = model.predict([[22, 1], [28, 1]])
pre
# Out:
# c:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Jazz'], dtype=object)

# %%
from sklearn import tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
tree.plot_tree(model, 
               feature_names=['age','gender'], 
               class_names=model.classes_, 
               filled=True)
plt.show()
